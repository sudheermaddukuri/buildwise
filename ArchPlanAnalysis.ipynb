# %% [markdown]
# <a href="https://colab.research.google.com/github/sudheermaddukuri/buildwise/blob/main/ArchPlanAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.1/155.1 kB 5.9 MB/s eta 0:00:00

# %%
import google.generativeai as genai
from google.colab import files
import PIL.Image

# 1. SETUP API KEY
from google.colab import userdata
# GOOGLE_API_KEY = userdata.get('AIzaSyCNkYJti9NTJs-yQEt2rxCxSZcQIZP6gM0')
genai.configure(api_key='AIzaSyCNkYJti9NTJs-yQEt2rxCxSZcQIZP6gM0')

# 2. UPLOAD ARCHITECTURAL PDF
print("Please upload your Architectural Plans (PDF):")
uploaded = files.upload()
file_path = list(uploaded.keys())[0]

# 3. LIST AVAILABLE MODELS AND THEIR METHODS
print("\n--- AVAILABLE GENERATIVE MODELS ---\n")
for m in genai.list_models():
  if "generateContent" in m.supported_generation_methods:
    print(f"Model Name: {m.name}, Supported methods: {m.supported_generation_methods}")

# 4. INITIALIZE MODEL (Placeholder - User will choose based on output above)
# model = genai.GenerativeModel('gemini-pro')

# 5. DEFINE THE MASTER PROMPT (As defined in Part 1)
master_prompt = """
# ROLE
Lead Architectural AI & Texas Residential Code Specialist.

# REASONING PHASES (MANDATORY CHAIN-OF-THOUGHT)
1. [cite_start]**COORDINATE ANCHOR:** Identify North, the street frontage (e.g., Brett Drive), and the cardinal map to establish solar exposure[cite: 101, 558].
2. [cite_start]**QUANTITATIVE AUDIT:** Conduct a sheet-by-sheet extraction of all physical assets (Windows, Doors, Electrical fixtures) [cite: 2-9].
3. [cite_start]**SPATIAL HIERARCHY:** Assign every room to a Level and determine its Cardinal Orientation (N/S/E/W) to assess thermal impact [cite: 5-6, 10-11].
4. **TEXAS CODE & INDEX COMPLIANCE:** * Check Egress (IRC §R310).
   * [cite_start]Verify Natural Light (8% rule)[cite: 125].
   * Calculate Performance Indices (Livability, Happiness, Thermal, and Acoustic).

# EXTRACTION RULES
- [cite_start]**Room Data:** Extract all spaces: BR, WIC, Powder, Mech, Laundry, Mudroom, Garage[cite: 180, 196, 204, 206, 223].
- [cite_start]**Dimensions:** Use annotated dimensions (e.g., 22'-6" X 20'-4")[cite: 244]. If unknown, use 0.
- [cite_start]**Orientation:** Base this on the Site Plan and Front Elevation[cite: 98, 412].

# OUTPUT STAGE 1: THE EXECUTION ROADMAP
Structure the advice into builder-specific construction phases:

### Phase 1: Foundation & Shell (Thermal Envelope)
* **Goal:** Mitigate West-facing solar heat gain.
* [cite_start]**Instruction:** Identify rooms with Western glass (e.g., Great Room or Gym) and specify Low-E glass with SHGC < 0.20[cite: 57, 122, 452].

### Phase 2: Framing & MEP (Core)
* **Goal:** Optimize Light & Acoustics.
* [cite_start]**Instruction:** Suggest solid-core doors or offset framing for Media and Office zones to improve Acoustic scores[cite: 160, 223].
* [cite_start]**Compliance:** Flag any bedroom lacking secondary egress[cite: 125].

### Phase 3: Finishes & Flow (Experience)
* **Goal:** Maximize Happiness (HX) and Livability (LX).
* [cite_start]**Instruction:** Enhance the "Golden Path" (e.g., Master Bath-to-Laundry accessibility)[cite: 189, 196].

# OUTPUT STAGE 2: DETERMINISTIC JSON
{
  "projectInfo": { "address": "String", "totalSqFt": 0 },
  "roomAnalysis": [
    {
      "name": "String",
      "level": Integer,
      "orientation": "N|S|E|W",
      "areaSqFt": 0,
      "indices": { "happiness": 0, "livability": 0, "thermal_risk": "Low|High" }
    }
  ]
}
"""

# 6. PROCESS AND ANALYZE
def analyze_plans(path, prompt):
    # Upload file to Gemini File API
    plan_file = genai.upload_file(path=path)

    # Generate content
    # !!! IMPORTANT: Replace 'gemini-pro' with a model from the list above that supports 'generateContent' and multimodal input if necessary.
    # For multimodal models, you might need a model like 'gemini-pro-vision' or similar if available.
    model = genai.GenerativeModel('gemini-pro-latest') # Updated to use a suitable model
    response = model.generate_content([plan_file, prompt])

    return response.text

# 7. RUN AUDIT (This will still fail until a valid model is chosen)
result = analyze_plans(file_path, master_prompt)
print("\n--- ARCHITECTURAL AUDIT REPORT ---\n")
print(result)

# print("Please review the list of available models above and update the 'model = genai.GenerativeModel(...)' line with a suitable model.")
# Out:
# Please upload your Architectural Plans (PDF):
#      <input type="file" id="files-9d25d0b4-407d-47f4-a858-f5bd7b575bc1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d25d0b4-407d-47f4-a858-f5bd7b575bc1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
